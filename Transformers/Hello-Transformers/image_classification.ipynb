# %% [markdown]
# # Image Classification

# %%
from transformers import pipeline
import requests
from PIL import Image

# %%
classifier = pipeline("image-classification")

url = "https://images.unsplash.com/photo-1501785888041-af3ef285b470"

result = classifier(url)

for r in result:

    print(f"{r['label']} → {r['score']:.2f}")
# Out:
# No model was supplied, defaulted to google/vit-base-patch16-224 and revision 3f49326 (https://huggingface.co/google/vit-base-patch16-224).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Fast image processor class <class 'transformers.models.vit.image_processing_vit_fast.ViTImageProcessorFast'> is available for this model. Using slow image processor class. To use the fast image processor class set `use_fast=True`.
# Device set to use mps:0
# canoe → 0.33
# valley, vale → 0.21
# paddle, boat paddle → 0.13
# lakeside, lakeshore → 0.11
# alp → 0.06

# %%
result
# Out:
# [{'label': 'canoe', 'score': 0.33290964365005493},
#  {'label': 'valley, vale', 'score': 0.21040868759155273},
#  {'label': 'paddle, boat paddle', 'score': 0.13022713363170624},
#  {'label': 'lakeside, lakeshore', 'score': 0.11225573718547821},
#  {'label': 'alp', 'score': 0.05982634797692299}]
