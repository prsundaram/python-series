# %% [markdown]
# # 🐧 Data Visualization with Seaborn
#
# 📌 **Objective:**
# Understand the basics of **Seaborn**, a Python data visualization library built on top of **Matplotlib**, designed to make statistical plotting **simpler, more powerful, and visually appealing**.
#
# ---
#
# ## 🧠 What is Seaborn?
#
# **Seaborn** provides a **high-level interface** for creating complex and informative plots with minimal code.
# It comes with **built-in themes, color palettes, and statistical tools** — letting you focus on insights, not styling.
#
# $$[
# \text{Matplotlib} \Rightarrow \text{Low-level control (more code)} \\
# \text{Seaborn} \Rightarrow \text{High-level abstraction (less code, better visuals)}
# ]$$
#
# ---
#
# ## 🎯 Why Use Seaborn?
#
# | Feature | Description |
# |:--------|:-------------|
# | 🌈 **Beautiful by default** | Comes with built-in color palettes and styles |
# | 📊 **Statistical power** | Automatically handles distributions, regression lines, and categories |
# | 🧩 **Integration with Pandas** | Works directly with DataFrames and column names |
# | 📈 **Complex plots made easy** | Create pairplots, heatmaps, violin plots, and regressions in one line |
# | 🧮 **Themes and palettes** | Customize entire visuals with `set_style()` and `set_palette()` |
#
# ---

# %%
# Installing Seaborn
# !pip install seaborn

# %%
import seaborn as sns       # Import Seaborn
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # 📊 Basic Plotting with Seaborn
#
# 📌 **Objective:**
# Learn how to create simple and insightful visualizations using Seaborn — starting with a **scatter plot** to show relationships between two continuous variables.
#
# ---
#
# ## 🧠 About the Dataset
#
# We’ll use Seaborn’s built-in **`tips`** dataset —
# a collection of restaurant bills and tips, with columns like:
# - `total_bill` — total amount of the bill
# - `tip` — amount of tip given
# - `sex` — gender of the person who paid
# - `smoker` — whether they were smokers
# - `day` — day of the week
# - `time` — Lunch/Dinner
# - `size` — number of people at the table
#
# ---
#
# ## 🔹 Step-by-Step Explanation
#
# | Step | Description |
# |:------|:-------------|
# | 1️⃣ | Load Seaborn’s sample dataset `tips` |
# | 2️⃣ | Use `sns.scatterplot()` to visualize relationship between `total_bill` and `tip` |
# | 3️⃣ | Customize plot with title, labels, and grid |
# | 4️⃣ | Display plot using `plt.show()` |

# %%
# --------------------------------------------------------
# 📊 Basic Scatter Plot using Seaborn
# --------------------------------------------------------

# 🧠 Step 1: Load sample dataset
tips = sns.load_dataset('tips')  # Preloaded dataset of restaurant bills and tips

# 🧾 Step 2: Inspect first few records
display(tips.head())

# 🧩 Step 3: Create scatter plot
plt.figure(figsize=(8, 5))  # Optional: set figure size
sns.scatterplot(
    x='total_bill',          # X-axis: total bill amount
    y='tip',                 # Y-axis: tip amount
    data=tips,               # Data source (DataFrame)
    color='royalblue',       # Point color
    edgecolor='black',       # Outline for better contrast
    s=80,                    # Dot size
    alpha=0.7                # Transparency for overlapping points
)

# 🏷️ Step 4: Add chart title and labels
plt.title('Scatter Plot of Total Bill vs Tip', fontsize=14, fontweight='bold')
plt.xlabel('Total Bill (in $)', fontsize=12)
plt.ylabel('Tip Amount (in $)', fontsize=12)

# 🧾 Step 5: Add gridlines for readability
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ✅ Output Explanation
# - Each point represents one restaurant bill.
# - The X-axis shows the total bill, and the Y-axis shows the tip amount.
# - You can visually observe that larger bills generally lead to higher tips — a clear positive correlation.
# ---
# | Tip                    | Description                                                           |
# | :--------------------- | :-------------------------------------------------------------------- |
# | 🧩 Add color grouping  | Use `hue='sex'` or `hue='day'` to color by category                   |
# | 🎨 Change theme        | `sns.set_style('whitegrid')` or `sns.set_context('talk')`             |
# | 🧮 Add regression line | Use `sns.lmplot(x='total_bill', y='tip', data=tips)`                  |
# | 🧱 Control size        | `s=100` for larger dots or use `size='size'` for dynamic bubble sizes |
# | 💾 Save chart          | `plt.savefig('scatter_totalbill_tip.png', dpi=300)`                   |
#
# ---
#
# ## 🧩 Example: Add Grouping by Day (Colored Scatter)

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(
    x='total_bill', y='tip',
    hue='day', data=tips, s=90, alpha=0.8, edgecolor='black'
)

plt.title('Scatter Plot of Total Bill vs Tip (by Day)', fontsize=14, fontweight='bold')
plt.xlabel('Total Bill ($)')
plt.ylabel('Tip ($)')
plt.legend(title='Day', loc='upper left')
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 📈 Line Plot using Seaborn
#
# 📌 **Objective:**
# Learn how to create a **line plot** in Seaborn to show how a numerical variable changes with respect to another variable —
# for example, how the **total bill** varies based on the **party size** at a restaurant.
#
# ---
#
# ## 🧠 When to Use a Line Plot
#
# | Use Case | Description |
# |:-----------|:-------------|
# | ⏱️ Time Series | Show trends over time (e.g., monthly revenue, weekly traffic) |
# | 📏 Continuous Data | Visualize changes in one variable relative to another |
# | 🧩 Averages per Group | Display average values for grouped data |
# | 📊 Trend Visualization | Identify upward, downward, or stable trends |
#
# ---
#
# ## 🔹 Step-by-Step Explanation
#
# | Step | Description |
# |:------|:-------------|
# | 1️⃣ | Load the dataset (`tips`) |
# | 2️⃣ | Use `sns.lineplot()` to plot `total_bill` vs `size` |
# | 3️⃣ | Add title, labels, and customize style |
# | 4️⃣ | Display the final chart |

# %%
# --------------------------------------------------------
# 📈 Basic Line Plot using Seaborn
# --------------------------------------------------------

# 🧠 Step 1: Load the sample dataset
tips = sns.load_dataset('tips')

# 🧾 Step 2: Inspect first few rows (optional)
display(tips.head())

# 🧩 Step 3: Create a simple line plot
plt.figure(figsize=(8, 5))
sns.lineplot(
    x='size',              # X-axis: party size (number of people)
    y='total_bill',        # Y-axis: total bill amount
    data=tips,             # Data source
    color='teal',          # Line color
    marker='o',            # Add circular markers at data points
    linewidth=2,           # Line thickness
    markersize=8,          # Marker size
    alpha=0.9              # Transparency level
)

# 🏷️ Step 4: Add labels and title
plt.title('Line Plot of Total Bill by Party Size', fontsize=14, fontweight='bold')
plt.xlabel('Party Size', fontsize=12)
plt.ylabel('Total Bill ($)', fontsize=12)

# 🧾 Step 5: Add gridlines for better readability
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ✅ Output Explanation
#
# You’ll see:
# - The X-axis shows the number of people at the table (size).
# - The Y-axis shows the average total bill amount.
# - The teal line indicates that as group size increases, the total bill also increases — a logical trend!
#
# ---
#
# | Tip                          | Description                                                  |
# | :--------------------------- | :----------------------------------------------------------- |
# | 🧮 Aggregate automatically   | Use `estimator='mean'` to plot averages per group            |
# | 🌈 Add multiple lines        | Use `hue='sex'` or `hue='day'` to compare trends             |
# | 🧱 Show confidence intervals | Set `ci='sd'` or `ci=None` to control shading                |
# | 🎨 Change theme              | Use `sns.set_style('darkgrid')` or `sns.set_context('talk')` |
# | 💾 Save figure               | `plt.savefig('lineplot_totalbill_size.png', dpi=300)`        |
# ---
# ## 🧩 Example: Comparing by Day (Multiple Lines)

# %%
# Multiple line plot comparing Total Bill by Day and Size
plt.figure(figsize=(10, 6))
sns.lineplot(
    x='size', y='total_bill',
    hue='day',                # Separate lines for each day
    data=tips,
    marker='o',
    linewidth=2,
    palette='Set2'            # Beautiful built-in color palette
)

plt.title('Total Bill vs Party Size by Day', fontsize=14, fontweight='bold')
plt.xlabel('Party Size')
plt.ylabel('Total Bill ($)')
plt.legend(title='Day of Week')
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ✅ Enhanced Output Insight
# - Each line represents a different day of the week.
# - The pattern shows which days tend to have larger party sizes or higher spending.
# - Using `hue='day'` helps you instantly spot day-wise variations 🎯

# %% [markdown]
# # 📊 Categorical Variable Plot — Bar Plot in Seaborn
#
# 📌 **Objective:**
# Visualize how a **numerical variable** (like total bill) changes across different **categories** (like days of the week).
# This helps identify which categories perform better or worse — for instance, which day earns the most at a restaurant.
#
# ---
#
# ## 🧠 What is a Bar Plot?
#
# A **Bar Plot** shows the **mean (average)** value of a numerical variable for each category.
# It automatically calculates the **central tendency** (by default, the *mean*) for each group and displays confidence intervals as error bars.
#
# $$[
# \text{Bar height} = \text{Mean of } Y \text{ for each category in } X
# ]$$
#
# ---
#
# ### 🔹 When to Use a Bar Plot
#
# | Use Case | Description |
# |:-----------|:-------------|
# | 🍽️ Restaurant Analysis | Compare average bills or tips by day |
# | 🛍️ Sales Reports | Compare revenue by region or category |
# | 🎓 Education | Average scores by department or grade |
# | 🏢 HR | Average salary by job title or department |
#
# ---
#
# ## 🧩 Example 1: Basic Bar Plot

# %%
# --------------------------------------------------------
# 📊 Bar Plot - Average Total Bill by Day
# --------------------------------------------------------

# 🧠 Step 1: Load sample dataset
tips = sns.load_dataset('tips')

# 🧾 Step 2: Inspect first few records (optional)
display(tips.head())

# 🧩 Step 3: Create basic bar plot
plt.figure(figsize=(8, 5))
sns.barplot(
    x='day',                  # X-axis: categorical variable (Day of the week)
    y='total_bill',           # Y-axis: numerical variable (Total bill amount)
    data=tips,                # Data source
    color='teal',             # Bar color (optional override)
    edgecolor='black',        # Outline color
    errorbar='sd',            # Show standard deviation as error 
    err_kws={'color': 'red'}  # color for the error
)

# 🏷️ Step 4: Add labels, title, and grid
plt.title('Bar Plot of Average Total Bill by Day', fontsize=14, fontweight='bold')
plt.xlabel('Day of the Week', fontsize=12)
plt.ylabel('Average Total Bill ($)', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ✅ Output Explanation
# - Each bar shows the average total bill for that day of the week.
# - The black lines (error bars) indicate variation (standard deviation) within each day.
# - This helps quickly identify which days have higher average bills (e.g., weekends 🥂).
#
# ---
# ## 🧩 Example 2: Bar Plot Grouped by Gender (Using hue)

# %%
# --------------------------------------------------------
# 📊 Grouped Bar Plot - Total Bill by Day and Gender
# --------------------------------------------------------

plt.figure(figsize=(8, 5))
sns.barplot(
    x='day', y='total_bill',
    hue='sex',               # Separate bars for Male/Female
    data=tips,
    palette='Set2',          # Soothing color palette
    edgecolor='black',
    errorbar='sd'
)

plt.title('Average Total Bill by Day and Gender', fontsize=14, fontweight='bold')
plt.xlabel('Day of the Week', fontsize=12)
plt.ylabel('Average Total Bill ($)', fontsize=12)
plt.legend(title='Gender')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 📦 Box Plot using Seaborn
#
# 📌 **Objective:**
# Learn how to visualize the **distribution and spread** of numerical data across categories using Seaborn’s `boxplot()`.
# Box plots show where most of your data lies and help identify **outliers** (unusually high or low values).
#
# ---
#
# ## 🧠 What is a Box Plot?
#
# A **Box Plot** displays the **five-number summary** of a dataset:
#
# | Metric | Description |
# |:--------|:-------------|
# | Minimum | The smallest data point excluding outliers |
# | Q1 (25th percentile) | The lower quartile — 25% of data lies below this value |
# | Median (Q2) | The middle value of the dataset |
# | Q3 (75th percentile) | The upper quartile — 75% of data lies below this value |
# | Maximum | The largest data point excluding outliers |
#
# ---
#
# ### 🔹 Understanding the Structure
#
# A box plot visually shows:

# %% [markdown]
# ```sccs
#       ●    ← Outliers (extreme values)
# ─────┤│─────  ← Whiskers (min & max)
#      ││
#   ┌──┼┼──┐    ← Box (middle 50% of data: Q1–Q3)
#      └┼┘
#       │
#      Median
# ```

# %% [markdown]
# - The **box** shows the middle 50% of data (interquartile range — IQR).
# - The **line inside** the box is the **median (Q2)**.
# - The **whiskers** extend to the lowest and highest non-outlier values.
# - The **dots beyond whiskers** are **outliers** — unusual points that deviate significantly from others.
#
# ---
#
# ## ⚠️ What Are Outliers?
#
# **Outliers** are data points that fall significantly outside the normal range of values.
#
# Mathematically, any value beyond:
#
# $$[
# \text{Outlier if } x < Q1 - 1.5 \times IQR \quad \text{or} \quad x > Q3 + 1.5 \times IQR
# ]$$
#
# where
# $$[
# IQR = Q3 - Q1
# ]$$
#
# Outliers are not always “bad” — they can indicate:
# - Errors or anomalies in data entry
# - Special events (e.g., huge tips or promotions)
# - Legitimate rare occurrences
#
# ---
#
# ## 🧩 Example 1: Basic Box Plot

# %%
# --------------------------------------------------------
# 📦 Basic Box Plot using Seaborn
# --------------------------------------------------------


# 🧠 Step 1: Load sample dataset
tips = sns.load_dataset('tips')

# 🧩 Step 2: Create box plot for total bill by day
plt.figure(figsize=(8, 5))
sns.boxplot(
    x='day',                # Categorical variable (X-axis)
    y='total_bill',         # Numerical variable (Y-axis)
    data=tips,              # Data source
    palette='Set2',         # Beautiful color palette
    width=0.6,              # Box width
    fliersize=6,            # Size of outlier markers
    linewidth=1.5,          # Line thickness
    hue = 'day'
)

# 🏷️ Step 3: Add labels, title, and grid
plt.title('Box Plot of Total Bill by Day', fontsize=14, fontweight='bold')
plt.xlabel('Day of the Week', fontsize=12)
plt.ylabel('Total Bill ($)', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ✅ Output Explanation
# - Each box represents the distribution of total bills for that day.
# - The median line shows the central value (typical bill).
# - The height of the box represents variability (IQR).
# - Dots outside whiskers are outliers, i.e., unusually high or low bills — maybe a party of 10 🍾
#
# ## 🧩 Example 2: Box Plot Grouped by Gender

# %%
# --------------------------------------------------------
# 📦 Box Plot - Total Bill by Day and Gender
# --------------------------------------------------------

plt.figure(figsize=(8, 5))
sns.boxplot(
    x='day', y='total_bill',
    hue='sex',                # Separate boxes by gender
    data=tips,
    palette='pastel',
    width=0.6,
    linewidth=1.4,
    fliersize=5
)

plt.title('Total Bill Distribution by Day and Gender', fontsize=14, fontweight='bold')
plt.xlabel('Day of the Week')
plt.ylabel('Total Bill ($)')
plt.legend(title='Gender')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ✅ Enhanced Output Insight
# - Now each day has two boxes — one for each gender.
# - You can visually compare spending behavior between men and women per day.
# - Outliers (points beyond whiskers) highlight days with exceptionally high bills.
#
# ---
# | Tip                    | Description                                            |
# | :--------------------- | :----------------------------------------------------- |
# | 🎨 Change style        | Use `sns.set_style('whitegrid')` for clarity           |
# | 🧮 Show swarm over box | Combine with `sns.swarmplot()` to show all data points |
# | ⚙️ Remove outliers     | Use `showfliers=False` to hide them                    |
# | 🌈 Change palette      | Try `'coolwarm'`, `'muted'`, or `'husl'`               |
# | 💾 Save chart          | `plt.savefig('boxplot_totalbill_day.png', dpi=300)`    |

# %% [markdown]
# ## 🧩 Example 3: Overlay Swarm Plot for Individual Data Points

# %%
# --------------------------------------------------------
# 📦 Box + Swarm Plot for Detailed View
# --------------------------------------------------------

plt.figure(figsize=(8, 5))
sns.boxplot(x='day', y='total_bill', data=tips, palette='Set3', width=0.6, hue='day')
sns.swarmplot(x='day', y='total_bill', data=tips, palette='dark:black', size=4, alpha=0.7, hue='day')

plt.title('Box + Swarm Plot of Total Bill by Day', fontsize=14, fontweight='bold')
plt.xlabel('Day of the Week')
plt.ylabel('Total Bill ($)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ✅ Output Explanation
# - The box plot summarizes data distribution.
# - The swarm plot overlays each actual data point.
# - This combo gives you both summary statistics and raw data visibility — perfect for exploratory analysis 🔍

# %% [markdown]
# ## 🧮 Understanding IQR and Outliers
#
# 📌 **Objective:**
# Before we interpret box plots, it’s important to understand two key ideas —
# **IQR (Interquartile Range)** and **Outliers**.
#
# ---
#
# ### 🔹 What is IQR?
#
# **IQR (Interquartile Range)** tells us how *spread out* the middle 50% of data is.
#
# It is calculated as:
#
# $[
# \text{IQR} = Q_3 - Q_1
# ]$
#
# where:
# - $( Q_1 )$ → 25th percentile (lower quartile)
# - $( Q_3 )$ → 75th percentile (upper quartile)
#
# 💡 Think of it like this:
# > The IQR covers the “normal range” where most data points live — it’s your *comfort zone* for values.
#
# ---
#
# ### 🔹 What are Outliers?
#
# **Outliers** are data points that are **much higher or lower** than the rest of the data.
# They fall *outside* the typical IQR range.
#
# Mathematically, any value is considered an **outlier** if it lies:
#
# $[
# x < Q_1 - 1.5 \times \text{IQR} \quad \text{or} \quad x > Q_3 + 1.5 \times \text{IQR}
# ]$
#
# 🟢 Most values lie within the box (inside the IQR).
# 🔴 Outliers appear as individual dots **beyond the whiskers** in a box plot.
#
# ---
#
# ### ✅ **Simple Summary**
#
# | Term | Meaning | Example |
# |:------|:----------|:-------------|
# | **Q1 (25%)** | Lower boundary of the middle range | ₹25 if 25% of bills are below this |
# | **Q3 (75%)** | Upper boundary of the middle range | ₹75 if 75% of bills are below this |
# | **IQR (Q3–Q1)** | Middle spread of values | ₹75 – ₹25 = ₹50 |
# | **Outliers** | Unusual values far away from the rest | ₹200 when most bills are ₹30–₹80 |
#
# ---
#
# 💬 **In simple words:**
# 👉 *IQR shows the middle chunk of data.*
# 👉 *Outliers are data points that “don’t fit in” — they’re too far away from the rest.*
#
# ---
#
# 🧠 Tip: Outliers aren’t always errors — they can represent **interesting cases**, like a huge restaurant bill or an exceptional sales day!

# %% [markdown]
# # 🎻 Violin Plot in Seaborn
#
# 📌 **Objective:**
# Learn how to visualize the **distribution and density** of numerical data across categories using the `sns.violinplot()` function.
# A **violin plot** combines the information of a **box plot** (median, quartiles, outliers) with a **smoothed density curve**, making it easier to understand *how values are spread*.
#
# ---
#
# ## 🧠 What is a Violin Plot?
#
# A **Violin Plot** shows:
# - The **median** (white dot or line inside)
# - The **interquartile range (IQR)** — middle 50% of values
# - The **distribution density** — the “width” of the violin shows where data is more frequent
#
# It’s called a *violin* because of its **symmetrical shape**, where the thickness represents the **concentration of data points**.
#
# ---
#
# ### 🔹 Box Plot vs. Violin Plot
#
# | Feature | Box Plot | Violin Plot |
# |:----------|:----------|:------------|
# | Shape | Rectangular box | Symmetrical “violin” |
# | Shows median & IQR | ✅ Yes | ✅ Yes |
# | Shows data density | ❌ No | ✅ Yes |
# | Handles multiple groups | ✅ Yes | ✅ Yes |
#
# 💡 **In short:**
# > The *violin plot* tells you *where* your data is concentrated — not just its range.
#
# ---
#
# ## 🧩 Example 1: Basic Violin Plot

# %%
# --------------------------------------------------------
# 🎻 Basic Violin Plot using Seaborn
# --------------------------------------------------------

# 🧠 Step 1: Load the sample dataset
tips = sns.load_dataset('tips')

# 🧾 Step 2: Inspect dataset
display(tips.head())

# 🧩 Step 3: Create violin plot for total bill by day
plt.figure(figsize=(8, 5))
sns.violinplot(
    x='day',                   # Categorical variable
    y='total_bill',            # Numerical variable
    data=tips,                 # Data source
    palette='muted',           # Color theme
    inner='box',               # Show mini box plot inside violin
    linewidth=1.2,             # Edge thickness
    hue='day'
)

# 🏷️ Step 4: Add title and labels
plt.title('Violin Plot of Total Bill by Day', fontsize=14, fontweight='bold')
plt.xlabel('Day of the Week', fontsize=12)
plt.ylabel('Total Bill ($)', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ✅ Output Explanation
# - Each “violin” represents the distribution of total bills for that day.
# - The wider sections indicate where more data points cluster.
# - The thin sections show where data is sparse.
# - The white dot (or line) inside shows the median.
# - The box inside the violin shows the IQR — the middle 50% of the data.
#
# ---
# ## 🧩 Example 2: Violin Plot Grouped by Gender

# %%
# --------------------------------------------------------
# 🎻 Grouped Violin Plot by Gender
# --------------------------------------------------------

plt.figure(figsize=(8, 5))
sns.violinplot(
    x='day', y='total_bill',
    hue='sex',                 # Split by gender
    data=tips,
    split=True,                # Show both genders in one violin
    palette='Set2',            # Color palette
    inner='quartile'           # Show quartile lines inside
)
sns.set_style('whitegrid')
plt.title('Total Bill Distribution by Day and Gender', fontsize=14, fontweight='bold')
plt.xlabel('Day of the Week')
plt.ylabel('Total Bill ($)')
plt.legend(title='Gender')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ✅ Enhanced Output Insight
# - Each “half” of a violin shows the distribution for one gender.
# - You can easily compare spending patterns between men and women across days.
# - Quartile lines inside show median and spread — a mix of stats and density 💪
#
# ---
# | Tip                  | Description                                            |
# | :------------------- | :----------------------------------------------------- |
# | 🎨 Change style      | Use `sns.set_style('whitegrid')` for readability       |
# | 🧮 Remove box inside | Set `inner=None` to show only the violin shape         |
# | ⚙️ Hide outliers     | Set `cut=0` to trim long tails                         |
# | 🌈 Color control     | Use `palette='coolwarm'`, `'mako'`, or `'pastel'`      |
# | 💾 Save figure       | `plt.savefig('violinplot_totalbill_day.png', dpi=300)` |
#
# ---
# ## 🧩 Example 3: Vertical → Horizontal Violin Plot

# %%
# --------------------------------------------------------
# 🎻 Horizontal Violin Plot
# --------------------------------------------------------

plt.figure(figsize=(7, 5))
sns.violinplot(
    y='day', x='total_bill',
    data=tips,
    palette='crest',
    inner='point',
    linewidth=1.3,
    hue='day'
)

plt.title('Horizontal Violin Plot - Total Bill by Day', fontsize=14, fontweight='bold')
plt.xlabel('Total Bill ($)')
plt.ylabel('Day of the Week')
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ✅ Output Explanation
# - The violin is now horizontal, great for dashboards or reports.
# - The width still represents data density, and quartile markers stay visible.
#
# 🧮 Quick Summary
# $$[
# \textbf{Violin Plot} = \textbf{Box Plot} + \textbf{Density Curve}
# ]$$
#
#
# 💬 In simple terms:
# > A box plot tells you how much and where,<br>
# > A violin plot tells you how much, where, and how often.

# %% [markdown]
# # 📊 Histogram in Seaborn
#
# 📌 **Objective:**
# Learn how to visualize the **distribution** of a numerical variable using Seaborn’s `histplot()` function.
# Histograms group data into **bins** and show how many observations fall into each bin — perfect for understanding the **shape, center, and spread** of your data.
#
# ---
#
# ## 🧠 What is a Histogram?
#
# A **Histogram** is a bar-like representation that shows how data values are distributed across **intervals (bins)**.
#
# Each bar’s height represents the **frequency** (or count) of observations within that bin.
#
# $$[
# \text{Frequency of a bin} = \text{Number of values falling within that range}
# ]$$
#
# ---
#
# ### 🔹 Key Terms
#
# | Term | Meaning |
# |:------|:-------------|
# | **Bins** | The number of equal-width intervals used to group data |
# | **KDE (Kernel Density Estimate)** | A smooth curve showing the probability density of the data |
# | **Skewness** | Tells whether the data is more spread on one side (left/right) |
# | **Mode** | The most frequently occurring value(s) |
#
# ---
#
# 💬 **In simple words:**
# > A histogram shows *how your data is spread out* — like a mountain range of your numbers ⛰️
#
# ---
#
# ## 🧩 Example 1: Basic Histogram

# %%
# --------------------------------------------------------
# 📊 Basic Histogram using Seaborn
# --------------------------------------------------------

# 🧠 Step 1: Load the dataset
tips = sns.load_dataset('tips')

# 🧩 Step 2: Create histogram for 'total_bill'
plt.figure(figsize=(8, 5))
sns.histplot(
    tips['total_bill'],   # Data column
    bins=10,              # Number of bins (intervals)
    kde=True,             # Add Kernel Density Estimate curve
    color='teal',         # Bar color
    edgecolor='black',    # Outline color for bars
    alpha=0.8             # Transparency
)

# 🏷️ Step 3: Add labels, title, and grid
plt.title('Distribution of Total Bill Amounts', fontsize=14, fontweight='bold')
plt.xlabel('Total Bill ($)', fontsize=12)
plt.ylabel('Frequency (Number of Customers)', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ✅ Output Explanation
# - Each bar shows how many customers had a bill in that price range.
# - The KDE line smooths the histogram to show the underlying shape (distribution curve).
# - You can see where most total bills fall — the “peak” of the data.
#
# ## 🧩 Example 2: Customize Bin Size and Add Styling

# %%
# --------------------------------------------------------
# 📊 Customized Histogram
# --------------------------------------------------------

plt.figure(figsize=(8, 5))
sns.histplot(
    data=tips,
    x='total_bill',
    bins=20,                  # More bins = more detail
    kde=True,
    color='coral',
    edgecolor='black',
    alpha=0.7
)

plt.title('Detailed Distribution of Total Bill', fontsize=14, fontweight='bold')
plt.xlabel('Total Bill ($)')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ✅ Enhanced Output Insight
# - More bins (20) give finer details of the distribution shape.
# - The KDE curve highlights the probability density — the smooth trend of where bills cluster.
#
# ---
# | Tip                    | Description                                             |
# | :--------------------- | :------------------------------------------------------ |
# | 🎨 Change color        | Use `palette='mako'` or `color='skyblue'`               |
# | ⚙️ Adjust bin size     | Use `bins=` to control granularity (e.g., 5 vs 30 bins) |
# | 🌈 Multiple histograms | Use `hue='sex'` to compare distributions by gender      |
# | 📈 Remove KDE          | Set `kde=False` for a pure histogram                    |
# | 💾 Save figure         | `plt.savefig('histplot_totalbill.png', dpi=300)`        |
#
# ---
# ## 🧩 Example 3: Comparing Distributions by Gender

# %%
# --------------------------------------------------------
# 📊 Multiple Histograms using hue
# --------------------------------------------------------

plt.figure(figsize=(8, 5))
sns.histplot(
    data=tips,
    x='total_bill',
    hue='sex',             # Separate histograms by gender
    bins=15,
    kde=True,
    multiple='stack',      # Overlapping ('layer') or stacked view
    palette='Set2',
    edgecolor='black',
    alpha=0.9
)

plt.title('Distribution of Total Bill by Gender', fontsize=14, fontweight='bold')
plt.xlabel('Total Bill ($)')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ✅ Output Explanation
# - Two distributions (for Male and Female) are stacked or overlaid.
# - Helps you compare spending patterns between groups.
# - KDE curves show smooth trends for each group separately.
#
# ---
# 🧮 Quick Formula Summary
#
# $$[
# \textbf{Histogram Height (Bin)} = \text{Count of data points within bin range}
# ]$$
#
# $$[
# \textbf{KDE Curve} \approx \text{Smooth estimate of the underlying probability density}
# ]$$

# %% [markdown]
# # 🌊 KDE Plot (Kernel Density Estimate) in Seaborn
#
# 📌 **Objective:**
# Understand and visualize the **probability distribution** of a numerical variable using `sns.kdeplot()`.
# A KDE Plot shows where your data points are **most concentrated** by estimating the underlying continuous distribution.
#
# ---
#
# ## 🧠 What is a KDE Plot?
#
# A **KDE (Kernel Density Estimate)** plot is a **smoothed version of a histogram**.
# Instead of grouping data into bars (bins), it draws a **continuous curve** representing the estimated probability density function (PDF).
#
# $$[
# \text{KDE}(x) = \frac{1}{n h} \sum_{i=1}^{n} K\left(\frac{x - x_i}{h}\right)
# ]$$
#
# where:
# - \( K \) = kernel function (usually Gaussian)
# - \( h \) = bandwidth (controls smoothness)
# - \( n \) = number of data points
#
# 💡 *In simple terms:*
# > KDE plots show the **shape** of your data — how it’s spread and where it peaks

# %%
# --------------------------------------------------------
# 🌊 Basic KDE Plot using Seaborn
# --------------------------------------------------------

# 🧠 Step 1: Load dataset
tips = sns.load_dataset('tips')

# 🧩 Step 2: Create a KDE plot
plt.figure(figsize=(8, 5))
sns.kdeplot(
    data=tips['total_bill'],  # Data column to plot
    fill=True,                # Fill the area under the curve
    color='teal',             # Curve color
    linewidth=2,              # Curve thickness
    alpha=0.7                 # Transparency of fill
)

# 🏷️ Step 3: Add labels and title
plt.title('KDE Plot - Distribution of Total Bill', fontsize=14, fontweight='bold')
plt.xlabel('Total Bill ($)', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ✅ Output Explanation
# - The X-axis shows the variable’s range (total bill amounts).
# - The Y-axis shows the density — not the count, but relative frequency.
# - The area under the curve = 1 (represents total probability).
# - Peaks in the curve show where most data points lie (most common bill amounts).
#
# ---
# ## 🧩 Example 2: Comparing KDE Distributions by Gender

# %%
# --------------------------------------------------------
# 🌊 Multiple KDE Curves using hue
# --------------------------------------------------------

plt.figure(figsize=(8, 5))
sns.kdeplot(
    data=tips, 
    x='total_bill',
    hue='sex',                # Separate curves for Male/Female
    fill=True,                # Fill under each curve
    common_norm=False,        # Keep densities separate (don’t normalize together)
    palette='Set2',           # Nice color palette
    alpha=0.6,                # Transparency for overlapping areas
    linewidth=2
)

plt.title('KDE Plot - Distribution of Total Bill by Gender', fontsize=14, fontweight='bold')
plt.xlabel('Total Bill ($)')
plt.ylabel('Density')
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ✅ Enhanced Output Insight
# - Each curve represents the distribution for one gender.
# - The filled area helps visualize overlap — showing how spending patterns differ.
# - You can clearly see if one group tends to have higher or lower bills.
#
# | Tip                       | Description                                                        |
# | :------------------------ | :----------------------------------------------------------------- |
# | 🧩 Overlay with histogram | Use `sns.histplot(..., kde=True)`                                  |
# | ⚙️ Adjust smoothness      | Use `bw_adjust=0.5` (sharper) or `bw_adjust=2` (smoother)          |
# | 🌈 Multiple hues          | Compare by category using `hue='day'`                              |
# | 🧱 2D KDE plot            | Use `sns.kdeplot(x='total_bill', y='tip')` for joint distributions |
# | 💾 Save plot              | `plt.savefig('kde_totalbill.png', dpi=300)`                        |
#
#
# 🧮 Quick Formula Summary
#
# $$[
# \textbf{KDE Plot} = \text{Smoothed Probability Density of the Data}
# ]$$
#
# $$[
# \text{Area under the KDE curve} = 1
# ]$$
#
# $$[
# \textbf{Histogram (Bars)} \;\Rightarrow\; \textbf{KDE (Smooth Curve)}
# ]$$
#
# 💬 In simple words:
# > KDE plots tell you how your data is distributed and where it’s most common — <br>
# > like turning a jagged histogram into a smooth mountain range 🌄

# %% [markdown]
# # 🔗 Pair Plot in Seaborn
#
# 📌 **Objective:**
# Visualize **relationships between multiple numerical variables** simultaneously using Seaborn’s `pairplot()`.
# This is one of the best tools for **Exploratory Data Analysis (EDA)** — it lets you quickly spot **patterns, correlations, and outliers**.
#
# ---
#
# ## 🧠 What is a Pair Plot?
#
# A **Pair Plot** creates a **matrix of scatter plots** for every numerical column combination in your dataset.
# It also shows **histograms or KDE plots** on the diagonal to represent each variable’s distribution.
#
# $$[
# \text{Pair Plot} = \text{Scatter Plots for Each Variable Pair} + \text{Distribution Plots on the Diagonal}
# ]$$
#
# 💬 **In simple words:**
# > It’s like looking at every pair of columns to see how they relate — all at once!
#
# ---
#
# ### 🔹 When to Use a Pair Plot
#
# | Use Case | Description |
# |:-----------|:-------------|
# | 🧩 Data exploration | Understand patterns and relationships between features |
# | 📊 Correlation check | Identify variables that move together (positive/negative correlation) |
# | 🧮 Outlier detection | Spot extreme points that deviate from trends |
# | 🎓 ML preprocessing | Choose features that might have predictive relationships |
#
# ---
#
# ## 🧩 Example 1: Basic Pair Plot

# %%
# --------------------------------------------------------
# 🔗 Basic Pair Plot using Seaborn
# --------------------------------------------------------

# 🧠 Step 1: Load sample dataset
tips = sns.load_dataset('tips')

# 🧩 Step 2: Create pair plot
sns.pairplot(tips)

# 🏷️ Step 3: Add title to the overall figure
plt.suptitle('Pair Plot of Numerical Features in Tips Dataset', fontsize=14, fontweight='bold', y=1.02)
plt.show()

# %% [markdown]
# ✅ Output Explanation
# - Each cell in the grid shows a scatter plot comparing two variables (e.g., total_bill vs tip).
# - The diagonal cells show a distribution (histogram or KDE) for each variable.
# - The plot instantly reveals correlations — for example, as total_bill increases, tip tends to increase too.
# ---
# ## 🧩 Example 2: Add Hue for Category Separation

# %%
# --------------------------------------------------------
# 🔗 Pair Plot with Hue (Categorical Grouping)
# --------------------------------------------------------

sns.pairplot(
    data=tips,
    hue='sex',             # Color by gender
    palette='Set2',        # Use soothing color palette
    diag_kind='kde',       # Use KDE instead of histogram for diagonals
    corner=False           # Show full grid (can set True to show only lower triangle)
)

plt.suptitle('Pair Plot of Tips Dataset Grouped by Gender', fontsize=14, fontweight='bold', y=1.02)
plt.show()

# %% [markdown]
# ✅ Enhanced Output Insight
# - Each point’s color represents a category (e.g., Male or Female).
# - You can visually compare distributions and correlations for each group.
# - The KDE diagonal provides smooth, continuous distribution curves.
# ---
# ## 🧩 Example 3: Focus on Selected Columns

# %%
# --------------------------------------------------------
# 🔗 Pair Plot for Selected Columns
# --------------------------------------------------------

cols = ['total_bill', 'tip', 'size', 'sex']
sns.pairplot(
    data=tips[cols],
    diag_kind='kde',
    palette='coolwarm',
    hue='sex'
)

plt.suptitle('Pair Plot - Total Bill, Tip, Size, and Gender', fontsize=14, fontweight='bold', y=1.02)
plt.show()

# %% [markdown]
# ✅ Output Explanation
# - Only selected columns are shown, reducing clutter.
# - Makes it easier to focus on the most important numerical relationships — like how size affects total_bill and tip.
#
# | Tip                      | Description                                   |
# | :----------------------- | :-------------------------------------------- |
# | 🎨 Style control         | Use `sns.set_style('ticks')` or `'whitegrid'` |
# | 🔍 Reduce clutter        | Use `corner=True` to show only half the grid  |
# | 🧱 Change diagonal plots | `diag_kind='hist'` (default) or `'kde'`       |
# | 🌈 Add color coding      | Use `hue='day'` or `hue='sex'` for grouping   |
# | 💾 Save figure           | `plt.savefig('pairplot_tips.png', dpi=300)`   |
#
# 🧮 Quick Formula Summary
#
# $$[
# \textbf{Pair Plot} = \text{Scatter Plots for Each Variable Pair} + \text{Distribution on Diagonal}
# ]$$
#
# $$[
# \textbf{Use:} \; \text{Explore Relationships, Correlations, and Distributions}
# ]$$
#
#
# 💬 In simple words:
# > A Pair Plot is like a visual correlation matrix — you see every relationship between your numerical variables at a glance.

# %% [markdown]
# # 🔥 Heatmap in Seaborn
#
# 📌 **Objective:**
# Visualize the **correlation strength** between numerical variables using Seaborn’s `heatmap()`.
# A heatmap uses **color intensity** to represent how strongly variables are related —
# making it easy to identify **positive, negative, or weak correlations**.
#
# ---
#
# ## 🧠 What is a Heatmap?
#
# A **Heatmap** is a graphical representation of data where values are shown as **color shades**.
# In correlation analysis, it helps us visualize how one numerical variable changes in relation to another.
#
# $$[
# \text{Correlation Coefficient (r)} = \frac{\text{Cov}(X, Y)}{\sigma_X \sigma_Y}
# ]$$
#
# Where:
# - \( r \) → ranges between **-1** and **+1**
# - \( r = +1 \) → Perfect positive correlation
# - \( r = -1 \) → Perfect negative correlation
# - \( r = 0 \) → No correlation
#
# ---
#
# ### 🔹 Interpreting Colors
#
# | Correlation (r) | Meaning | Color |
# |:----------------:|:--------|:------|
# | +1.0 | Strong positive relation | 🔴 Red |
# |  0.0 | No relation | ⚪ Neutral (white/light) |
# | -1.0 | Strong negative relation | 🔵 Blue |
#
# 💬 **In simple words:**
# > A heatmap turns numbers into colors, so your brain spots relationships instantly! 🎯
#
# ---
#
# ## 🧩 Example 1: Basic Correlation Heatmap

# %%
# --------------------------------------------------------
# 🔥 Correlation Heatmap using Seaborn
# --------------------------------------------------------

# 🧠 Step 1: Load dataset
tips = sns.load_dataset('tips')

# 🧾 Step 2: Inspect data
display(tips.head())

# 🧮 Step 3: Compute correlation matrix
correlation = tips[['total_bill', 'tip', 'size']].corr()

# 🧩 Step 4: Plot heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(
    correlation,        # Matrix to visualize
    annot=True,         # Display correlation values
    cmap='coolwarm',    # Color palette (blue → red)
    center=0,           # Center color map at 0
    linewidths=0.5,     # Add thin lines between cells
    fmt=".2f"           # Format annotation to 2 decimal places
)

# 🏷️ Step 5: Add title
plt.title('Correlation Heatmap of Numerical Features', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ✅ Output Explanation
# - Each cell shows the correlation coefficient (r) between two variables.
# - Red → strong positive relationship (values rise together).
# - Blue → strong negative relationship (one rises, the other falls).
# - White/light shades → weak or no relationship.
#
# For example:
# If `total_bill` and tip show a correlation near `+0.67`, it means larger bills usually mean larger tips 💸
#
# ---
#
# ## 🧩 Example 2: Full Dataset Heatmap

# %%
# --------------------------------------------------------
# 🔥 Full Feature Correlation Heatmap
# --------------------------------------------------------

# 🧮 Compute correlation for all numerical columns
corr_matrix = tips.corr(numeric_only=True)

plt.figure(figsize=(8, 5))
sns.heatmap(
    corr_matrix,
    annot=True,
    cmap='crest',
    center=0,
    linewidths=0.5,
    fmt=".2f"
)

plt.title('Full Correlation Heatmap - Tips Dataset', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ✅ Enhanced Output Insight
# - Displays correlations between all numeric columns in the dataset.
# - You can instantly see that:
#     - total_bill ↔ tip → strong positive correlation
#     - size ↔ total_bill → moderately positive correlation
#     - size ↔ tip → moderate relationship
#
# | Tip                     | Description                                                 |
# | :---------------------- | :---------------------------------------------------------- |
# | 🌈 Change color scale   | Try `cmap='viridis'`, `'YlGnBu'`, or `'coolwarm'`           |
# | 🧮 Customize formatting | Use `fmt='.3f'` for higher precision                        |
# | 📉 Remove diagonal      | Use `mask=np.triu(corr_matrix)` to show only lower triangle |
# | 🎨 Style theme          | Use `sns.set_style('white')` or `'darkgrid'`                |
# | 💾 Save plot            | `plt.savefig('heatmap_correlation.png', dpi=300)`           |
#
# 🧮 Quick Formula Summary
#
# $$[
# \textbf{Heatmap} = \text{Color-coded Matrix Representing Relationships Between Variables}
# ]$$
#
# $$[
# r = +1 \;\Rightarrow\; \text{Strong Positive Correlation}
# ]$$
#
# $$[
# r = -1 \;\Rightarrow\; \text{Strong Negative Correlation}
# ]$$
#
# $$[
# r = 0 \;\Rightarrow\; \text{No Linear Relationship}
# ]$$
#
#
# 💬 In simple words:
# > A heatmap lets you see relationships instead of calculating them — <br>
# > colors tell you whether variables move together, opposite, or independently.

# %% [markdown]
# # 💼 Real-World Example: Sales Data Visualization (Seaborn)
#
# 📌 **Objective:**
# Visualize **total sales revenue by product category** using a bar chart.
# This type of visualization helps identify which product categories generate the most revenue —
# a key insight in business intelligence and data-driven decision-making.
#
# ---
#
# ## 🧠 What You’ll Learn
# - How to read real-world sales data using `pandas.read_csv()`
# - How to group and summarize sales by category
# - How to create a **bar chart** of total revenue using `sns.barplot()`
#
# ---
#
# ## 🧩 Example: Total Sales by Product Category

# %%
# --------------------------------------------------------
# 💼 Plot Total Sales by Product Category
# --------------------------------------------------------

# 🧠 Step 1: Load the dataset
sales_data = pd.read_csv('sales_data.csv')

# 🧾 Step 2: Preview dataset
display(sales_data.head())

# 🧮 Step 3: Create bar plot of total revenue by product category
plt.figure(figsize=(10, 6))
sns.barplot(
    x='Product Category',        # Categorical variable
    y='Total Revenue',           # Numerical variable
    data=sales_data,             # Data source
    estimator=sum,               # Aggregate using sum (total revenue)
    palette='coolwarm',          # Color palette for aesthetics
    edgecolor='black',           # Border around bars
    hue='Product Category'

)

# 🏷️ Step 4: Add labels, title, and grid
plt.title('Total Sales by Product Category', fontsize=16, fontweight='bold')
plt.xlabel('Product Category', fontsize=12)
plt.ylabel('Total Revenue', fontsize=12)
plt.xticks(rotation=30, ha='right')   # Rotate labels for readability
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %% [markdown]
# ✅ Output Explanation
# - Each bar represents the total revenue contributed by one product category.
# - The height of the bar = total sales amount.
# - The color intensity helps visually differentiate categories.
# - You can easily identify top-performing products or underperformers.
#
# ---
#
# | Tip                    | Description                                                                |
# | :--------------------- | :------------------------------------------------------------------------- |
# | 🧮 Change aggregation  | Use `estimator=np.mean` for average sales instead of total                 |
# | 🎨 Palette options     | Try `palette='viridis'`, `'magma'`, or `'pastel'`                          |
# | 📊 Add annotations     | Use `plt.text()` to show exact revenue above bars                          |
# | ⚙️ Group data manually | Use `groupby('Product Category')['Total Revenue'].sum()` for preprocessing |
# | 💾 Save figure         | `plt.savefig('sales_by_category.png', dpi=300)`                            |

# %% [markdown]
# # 📊 Bivariate Relationships in Seaborn
#
# 📌 **Objective:**
# Understand how to visualize and analyze **relationships between two variables** —
# typically one **numerical** and one **categorical**, or two **numerical** variables.
#
# ---
#
# ## 🧠 What Are Bivariate Relationships?
#
# **Bivariate analysis** helps us explore how one variable changes with respect to another.
# It’s the bridge between simple descriptive statistics and deeper predictive insights.
#
# $$[
# \text{Bivariate Analysis} = \text{Exploring Relationships Between Two Variables}
# ]$$
#
# ---
#
# ### 🔹 Types of Bivariate Relationships
#
# | Type | Example | Visualization |
# |:------|:----------|:---------------|
# | **Numerical vs Numerical** | `total_bill` vs `tip` | Scatter Plot, Joint Plot, Regression Plot |
# | **Categorical vs Numerical** | `day` vs `total_bill` | Box Plot, Violin Plot, Bar Plot |
# | **Categorical vs Categorical** | `day` vs `sex` | Count Plot, Heatmap (cross-tab) |
#
# ---
#
# 💬 **In simple words:**
# > We now move from looking at single columns to **how two columns interact** —
# > spotting correlations, trends, and dependencies 🔍
#
# ---
#
# ## 🧩 Example 1: Numerical vs Numerical — Scatter Plot

# %%
# --------------------------------------------------------
# 📊 Scatter Plot: Total Bill vs Tip
# --------------------------------------------------------

# Load dataset
tips = sns.load_dataset('tips')

# Create scatter plot
plt.figure(figsize=(8, 5))
sns.scatterplot(
    data=tips,
    x='total_bill', 
    y='tip',
    color='teal', 
    edgecolor='black', 
    alpha=0.7
)

# Labels and title
plt.title('Relationship Between Total Bill and Tip', fontsize=14, fontweight='bold')
plt.xlabel('Total Bill ($)')
plt.ylabel('Tip Amount ($)')
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ✅ Interpretation
# - You can see that as total bill increases, the tip amount generally increases too — a positive correlation 💰
# - But not perfectly linear — some variability exists (depends on generosity, group size, etc.).
#
# ---
# ## 🧩 Example 2: Adding a Third Variable (Hue) to Show Patterns

# %%
# --------------------------------------------------------
# 📊 Scatter Plot with Hue
# --------------------------------------------------------

plt.figure(figsize=(8, 5))
sns.scatterplot(
    data=tips,
    x='total_bill',
    y='tip',
    hue='sex',             # Color by gender
    style='smoker',        # Marker shape by smoker status
    palette='Set2',
    s=90, alpha=0.8
)

plt.title('Total Bill vs Tip (by Gender and Smoker Status)', fontsize=14, fontweight='bold')
plt.xlabel('Total Bill ($)')
plt.ylabel('Tip Amount ($)')
plt.legend(title='Gender / Smoker')
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ✅ Enhanced Insight
# - You can instantly spot if men/women or smokers/non-smokers tend to tip more.
# - Adding hue or style introduces multi-dimensional understanding within a single 2D plot.
#
# ---
#
# ## 🧩 Example 3: Joint Plot — Distribution + Relationship

# %%
# --------------------------------------------------------
# 📈 Joint Plot: Combine Scatter + Distribution
# --------------------------------------------------------

sns.jointplot(
    data=tips,
    x='total_bill',
    y='tip',
    kind='scatter',      # Can also be 'kde', 'hex', or 'reg'
    color='teal'
).fig.suptitle('Joint Distribution of Total Bill and Tip', fontsize=14, fontweight='bold', y=1.02)
plt.show()

# %% [markdown]
# ✅ Output Explanation
# - The center plot shows the scatter relationship between variables.
# - The top and right histograms show each variable’s distribution individually.
# - This gives a complete picture of both spread and relationship strength.
#
# ---
# | Tip                    | Description                                               |
# | :--------------------- | :-------------------------------------------------------- |
# | 🎨 Add regression line | Use `sns.regplot()` or `kind='reg'` in `jointplot()`      |
# | 🧮 Change marker size  | Use `size='size'` or `s=100` for emphasis                 |
# | 🌈 Compare categories  | Add `hue='day'` for day-wise patterns                     |
# | ⚙️ Hexbin              | Use `kind='hex'` for large datasets to avoid overplotting |
# | 💾 Save figure         | `plt.savefig('bivariate_relationship.png', dpi=300)`      |

# %% [markdown]
# # 📈 Regression & Trend Line Visualization (Seaborn)
#
# 📌 **Objective:**
# Fit and visualize linear (and simple nonlinear) relationships between two numerical variables using Seaborn's `regplot` and `lmplot`.
# We will cover plotting the trend line, showing confidence intervals, controlling fit type, and inspecting residual behavior.
#
# ---
#
# ## 🧠 What is Regression (in this context)?
#
# Regression fits a function (commonly a straight line) that best describes the relationship between an independent variable \(x\) and a dependent variable \(y\).
#
# A simple linear regression model:
#
# $$[
# y \approx m x + b
# ]$$
#
# where:
# - \(m\) = slope (how much \(y\) changes for 1 unit of \(x\))
# - \(b\) = intercept
#
# Seaborn's regression plotting functions visualize both the scatter of points and the fitted trend line (with optional confidence interval).

# %%
# --------------------------------------------------------
# 📈 Example 1: Simple Linear Regression with sns.regplot()
# --------------------------------------------------------

# Load sample dataset
tips = sns.load_dataset('tips')

# Create scatter + regression line (default: linear fit with 95% CI)
plt.figure(figsize=(8, 5))
sns.regplot(
    data=tips,
    x='total_bill',          # Independent variable
    y='tip',                 # Dependent variable
    scatter_kws={'s': 60, 'edgecolor': 'black', 'alpha': 0.7},  # scatter point style
    line_kws={'color': 'crimson', 'linewidth': 2},              # regression line style
    ci=95,                   # 95% confidence interval band for the regression line
    marker='o'               # marker style for scatter points
)

plt.title('regplot: Tip vs Total Bill (Linear Fit with 95% CI)', fontsize=14, fontweight='bold')
plt.xlabel('Total Bill ($)')
plt.ylabel('Tip ($)')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Explanation (regplot)
# - `sns.regplot()` plots raw points and fits a regression model (by default linear).
# - `ci` shows an uncertainty band (confidence interval) around the fitted line — helpful to assess how certain the estimate is.
# - `scatter_kws` and `line_kws` let you style points and the fitted line.

# %%
# !pip install statsmodels

# %%
import statsmodels.api as sm
print("Statsmodels imported successfully ✅")
print("Version:", sm.__version__)
# Out:
# Statsmodels imported successfully ✅
# Version: 0.14.5

# %%
# --------------------------------------------------------
# 📈 Example 2: Linear Regression without Confidence Interval & robust fit
# --------------------------------------------------------

plt.figure(figsize=(8, 5))

# Ordinary linear fit without CI
sns.regplot(
    data=tips, x='total_bill', y='tip',
    ci=None,                    # Hide confidence interval
    scatter_kws={'s': 50, 'alpha': 0.6},
    line_kws={'color': 'navy', 'linewidth': 2, 'linestyle': '--'},
    label='OLS fit'
)

# Robust fit (low influence of outliers) using lowess (locally weighted scatterplot smoothing)
sns.regplot(
    data=tips, x='total_bill', y='tip',
    lowess=True,                # non-parametric locally-weighted regression (smooth curve)
    scatter=False,              # avoid plotting scatter again
    line_kws={'color': 'orange', 'linewidth': 2},
    label='LOWESS (smooth)'
)

plt.title('Linear vs LOWESS Fit (no CI)', fontsize=14, fontweight='bold')
plt.xlabel('Total Bill ($)')
plt.ylabel('Tip ($)')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Notes
# - `lowess=True` draws a smooth non-parametric curve useful when the relationship is not strictly linear.
# - Use `ci=None` to hide the confidence band when you prefer a cleaner visual.

# %%
# --------------------------------------------------------
# 📈 Example 3: Use sns.lmplot() for faceted regression (fit per category)
# --------------------------------------------------------

# lmplot returns a FacetGrid — great for comparing separate regression lines per group
sns.lmplot(
    data=tips,
    x='total_bill', y='tip',
    hue='sex',                 # separate regression per gender
    col='smoker',              # facet by smoker status (creates two panels)
    height=5, aspect=1,        # size of each facet
    scatter_kws={'s': 50, 'alpha': 0.6, 'edgecolor': 'black'},
    line_kws={'linewidth': 2}
)

# add a global title (suptitle)
plt.suptitle('lmplot: Regression by Sex and Smoker Status', fontsize=16, fontweight='bold', y=1.03)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Why use `lmplot`?
# - `lmplot` is handy when you want **separate fits per subgroup** (via `hue` or `col`/`row`) and automatic faceting.
# - It returns a `FacetGrid` so you can easily compare slopes/intercepts across categories.
